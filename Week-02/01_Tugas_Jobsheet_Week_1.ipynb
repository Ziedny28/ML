# %% [markdown]
# # Tugas Praktikum Week 1

# %% [markdown]
# Pada tugas pratikum ini Anda akan menggunakan data "Wisconsin Breast Cancer". Data tersebut terdiri dari 569 data yang digunakan untuk mendiagnonis jenis kanker Malignant (M) dan Benign (B). Tugas Anda adalah,
# 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.
# 2. Lakukan proses encoding pada kolom "diagnosis".
# 3. Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.
# 4. Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20

# %% [markdown]
# - Pada kode dibawah akan dilakukan import pandas, seaborn, dan matplotlib, mengimpor data dan menampilkan 5 data teratas dengan fungsi head

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = 'wbc.csv' # path dataset
wbc = pd.read_csv(data) # load dataset

wbc.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# - Menampilkan info data pada wbc, yang menunjukkan bahwa semua data Unnamed: 32 Null

# %%
wbc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# - mencari nilai null

# %%
wbc.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# ## Nomor 1 - Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.

# %% [markdown]
# - menghapus variable yang tidak digunakan menggunakan wbc head, disini yang tidak berguna adalah id dan unnamed: 32

# %%
wbc = wbc.drop(columns=['id', 'Unnamed: 32'])
wbc.head(100)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          M       17.990         10.38          122.80     1001.0
# 1          M       20.570         17.77          132.90     1326.0
# 2          M       19.690         21.25          130.00     1203.0
# 3          M       11.420         20.38           77.58      386.1
# 4          M       20.290         14.34          135.10     1297.0
# ..       ...          ...           ...             ...        ...
# 95         M       20.260         23.03          132.40     1264.0
# 96         B       12.180         17.84           77.79      451.1
# 97         B        9.787         19.94           62.11      294.5
# 98         B       11.600         12.84           74.34      412.6
# 99         M       14.420         19.77           94.48      642.5
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.11840           0.27760        0.300100             0.147100
# ...

# %%
wbc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ## Nomor 2 - Lakukan proses encoding pada kolom "diagnosis".

# %% [markdown]
# - menampilkan 100 data teratas

# %%
wbc.head(100)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          M       17.990         10.38          122.80     1001.0
# 1          M       20.570         17.77          132.90     1326.0
# 2          M       19.690         21.25          130.00     1203.0
# 3          M       11.420         20.38           77.58      386.1
# 4          M       20.290         14.34          135.10     1297.0
# ..       ...          ...           ...             ...        ...
# 95         M       20.260         23.03          132.40     1264.0
# 96         B       12.180         17.84           77.79      451.1
# 97         B        9.787         19.94           62.11      294.5
# 98         B       11.600         12.84           74.34      412.6
# 99         M       14.420         19.77           94.48      642.5
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.11840           0.27760        0.300100             0.147100
# ...

# %% [markdown]
# - melakukan enkoding dengan menggunakan LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
le = LabelEncoder() #object dari LabelEncoder
wbc['diagnosis'] = le.fit_transform(wbc['diagnosis']) # proses encoding
wbc.head(100)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           1       17.990         10.38          122.80     1001.0
# 1           1       20.570         17.77          132.90     1326.0
# 2           1       19.690         21.25          130.00     1203.0
# 3           1       11.420         20.38           77.58      386.1
# 4           1       20.290         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 95          1       20.260         23.03          132.40     1264.0
# 96          0       12.180         17.84           77.79      451.1
# 97          0        9.787         19.94           62.11      294.5
# 98          0       11.600         12.84           74.34      412.6
# 99          1       14.420         19.77           94.48      642.5
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# ## Nomor 3 - Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.

# %% [markdown]
# - melakukan standarisasi dengan fit_transform

# %%
std = StandardScaler()
wbc[['diagnosis','radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst']] = std.fit_transform(wbc[['diagnosis','radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','area_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','radius_worst','texture_worst','perimeter_worst','area_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst']])

# %%
wbc.head(100)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    1.297676     1.097064     -2.073335        1.269934   0.984375
# 1    1.297676     1.829821     -0.353632        1.685955   1.908708
# 2    1.297676     1.579888      0.456187        1.566503   1.558884
# 3    1.297676    -0.768909      0.253732       -0.592687  -0.764464
# 4    1.297676     1.750297     -1.151816        1.776573   1.826229
# ..        ...          ...           ...             ...        ...
# 95   1.297676     1.741776      0.870405        1.665360   1.732374
# 96  -0.770609    -0.553058     -0.337343       -0.584037  -0.579597
# 97  -0.770609    -1.232704      0.151341       -1.229900  -1.024984
# 98  -0.770609    -0.717787     -1.500877       -0.726143  -0.689095
# 99   1.297676     0.083133      0.111781        0.103427  -0.035236
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %% [markdown]
# ## Nomor 4 - Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20.

# %% [markdown]
# - melakuakan proses starttified split data untuk membuat data latih dan uji dengan rasio 80:20 menggunakan train_test_split

# %%
# Split data
from sklearn.model_selection import train_test_split
x = wbc
y = wbc['diagnosis']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, stratify=y)

# %%
print(f'jumlah data asli: {wbc.shape[0]}')
print(f'jumlah data latih y(diagnosis): {y_train.shape[0]}')
print(f'jumlah data latih x: {x_train.shape[0]}')
print(f'jumlah data uji y(diagnosis): {y_test.shape[0]}')
print(f'jumlah data uji x: {x_test.shape[0]}')

print(f'jumlah label data asli: \n{wbc.diagnosis.value_counts()}')
# print(f'jumlah label data latih y(diagnosis): \n{y_train.diagnosis.value_counts()}')
print(f'jumlah label data latih x: \n{x_train.diagnosis.value_counts()}')
# print(f'jumlah label data uji y(diagnosis): \n{y_test.diagnosis.value_counts()}')
print(f'jumlah label data uji x: \n{x_test.diagnosis.value_counts()}')
# Out:
# jumlah data asli: 569
# jumlah data latih y(diagnosis): 455
# jumlah data latih x: 455
# jumlah data uji y(diagnosis): 114
# jumlah data uji x: 114
# jumlah label data asli:
# -0.770609    357
#  1.297676    212
# Name: diagnosis, dtype: int64
# jumlah label data latih x:
# -0.770609    285
#  1.297676    170
# Name: diagnosis, dtype: int64
# jumlah label data uji x:
# -0.770609    72
#  1.297676    42
# Name: diagnosis, dtype: int64
